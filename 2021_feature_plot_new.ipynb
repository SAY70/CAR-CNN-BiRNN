# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_5_26_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\5_26_2021_LUM_new.xlsx'

df_5_26_21_all = pd.read_excel(LUM_5_26_21, sheet_name='5_26_21_ALL')


# 5_28_20
df_5_26_21_n_0   = df_5_26_21_all[(df_5_26_21_all['N'] == 0)   & (df_5_26_21_all['name'] == 3)]
df_5_26_21_n_157 = df_5_26_21_all[(df_5_26_21_all['N'] == 157) & (df_5_26_21_all['name'] == 3)]
df_5_26_21_n_280 = df_5_26_21_all[(df_5_26_21_all['N'] == 280) & (df_5_26_21_all['name'] == 3)]
df_5_26_21_n_403 = df_5_26_21_all[(df_5_26_21_all['N'] == 403) & (df_5_26_21_all['name'] == 3)]
df_5_26_21_n_526 = df_5_26_21_all[(df_5_26_21_all['N'] == 526) & (df_5_26_21_all['name'] == 3)]


df_5_26_21_rb_0   = df_5_26_21_all[(df_5_26_21_all['N'] == 0)   & (df_5_26_21_all['name'] == 2)]
df_5_26_21_rb_157 = df_5_26_21_all[(df_5_26_21_all['N'] == 157) & (df_5_26_21_all['name'] == 2)]
df_5_26_21_rb_280 = df_5_26_21_all[(df_5_26_21_all['N'] == 280) & (df_5_26_21_all['name'] == 2)]
df_5_26_21_rb_403 = df_5_26_21_all[(df_5_26_21_all['N'] == 403) & (df_5_26_21_all['name'] == 2)]
df_5_26_21_rb_526 = df_5_26_21_all[(df_5_26_21_all['N'] == 526) & (df_5_26_21_all['name'] == 2)]

df_5_26_21_no_280 = df_5_26_21_all[(df_5_26_21_all['N'] == 280) & (df_5_26_21_all['name'] == 1)]
df_5_26_21_no_392 = df_5_26_21_all[(df_5_26_21_all['N'] == 392) & (df_5_26_21_all['name'] == 1)]
df_5_26_21_no_504 = df_5_26_21_all[(df_5_26_21_all['N'] == 504) & (df_5_26_21_all['name'] == 1)]
df_5_26_21_no_616 = df_5_26_21_all[(df_5_26_21_all['N'] == 616) & (df_5_26_21_all['name'] == 1)]


df_5_26_21_alt_34  = df_5_26_21_all[(df_5_26_21_all['N'] == 34)  & (df_5_26_21_all['name'] == 4)]
df_5_26_21_alt_392 = df_5_26_21_all[(df_5_26_21_all['N'] == 392) & (df_5_26_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_5_26_21_n_0   = df_5_26_21_n_0.iloc[:, 4:]
df_5_26_21_n_157 = df_5_26_21_n_157.iloc[:, 4:]
df_5_26_21_n_280 = df_5_26_21_n_280.iloc[:, 4:]
df_5_26_21_n_403 = df_5_26_21_n_403.iloc[:, 4:]
df_5_26_21_n_526 = df_5_26_21_n_526.iloc[:, 4:]


df_5_26_21_rb_0   = df_5_26_21_rb_0.iloc[:, 4:]
df_5_26_21_rb_157 = df_5_26_21_rb_157.iloc[:, 4:]
df_5_26_21_rb_280 = df_5_26_21_rb_280.iloc[:, 4:]
df_5_26_21_rb_403 = df_5_26_21_rb_403.iloc[:, 4:]
df_5_26_21_rb_526 = df_5_26_21_rb_526.iloc[:, 4:]

df_5_26_21_no_280 = df_5_26_21_no_280.iloc[:, 4:]
df_5_26_21_no_392 = df_5_26_21_no_392.iloc[:, 4:]
df_5_26_21_no_504 = df_5_26_21_no_504.iloc[:, 4:]
df_5_26_21_no_616 = df_5_26_21_no_616.iloc[:, 4:]


df_5_26_21_alt_34  = df_5_26_21_alt_34.iloc[:, 4:]
df_5_26_21_alt_392 = df_5_26_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_01_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\6_01_2021_LUM_new.xlsx'

df_6_01_21_all = pd.read_excel(LUM_6_01_21, sheet_name='6_01_21_ALL')


# 5_28_20
df_6_01_21_n_0   = df_6_01_21_all[(df_6_01_21_all['N'] == 0)   & (df_6_01_21_all['name'] == 3)]
df_6_01_21_n_157 = df_6_01_21_all[(df_6_01_21_all['N'] == 157) & (df_6_01_21_all['name'] == 3)]
df_6_01_21_n_280 = df_6_01_21_all[(df_6_01_21_all['N'] == 280) & (df_6_01_21_all['name'] == 3)]
df_6_01_21_n_403 = df_6_01_21_all[(df_6_01_21_all['N'] == 403) & (df_6_01_21_all['name'] == 3)]
df_6_01_21_n_526 = df_6_01_21_all[(df_6_01_21_all['N'] == 526) & (df_6_01_21_all['name'] == 3)]


df_6_01_21_rb_0   = df_6_01_21_all[(df_6_01_21_all['N'] == 0)   & (df_6_01_21_all['name'] == 2)]
df_6_01_21_rb_157 = df_6_01_21_all[(df_6_01_21_all['N'] == 157) & (df_6_01_21_all['name'] == 2)]
df_6_01_21_rb_280 = df_6_01_21_all[(df_6_01_21_all['N'] == 280) & (df_6_01_21_all['name'] == 2)]
df_6_01_21_rb_403 = df_6_01_21_all[(df_6_01_21_all['N'] == 403) & (df_6_01_21_all['name'] == 2)]
df_6_01_21_rb_526 = df_6_01_21_all[(df_6_01_21_all['N'] == 526) & (df_6_01_21_all['name'] == 2)]

df_6_01_21_no_280 = df_6_01_21_all[(df_6_01_21_all['N'] == 280) & (df_6_01_21_all['name'] == 1)]
df_6_01_21_no_392 = df_6_01_21_all[(df_6_01_21_all['N'] == 392) & (df_6_01_21_all['name'] == 1)]
df_6_01_21_no_504 = df_6_01_21_all[(df_6_01_21_all['N'] == 504) & (df_6_01_21_all['name'] == 1)]
df_6_01_21_no_616 = df_6_01_21_all[(df_6_01_21_all['N'] == 616) & (df_6_01_21_all['name'] == 1)]


df_6_01_21_alt_34  = df_6_01_21_all[(df_6_01_21_all['N'] == 34)  & (df_6_01_21_all['name'] == 4)]
df_6_01_21_alt_392 = df_6_01_21_all[(df_6_01_21_all['N'] == 392) & (df_6_01_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_6_01_21_n_0   = df_6_01_21_n_0.iloc[:, 4:]
df_6_01_21_n_157 = df_6_01_21_n_157.iloc[:, 4:]
df_6_01_21_n_280 = df_6_01_21_n_280.iloc[:, 4:]
df_6_01_21_n_403 = df_6_01_21_n_403.iloc[:, 4:]
df_6_01_21_n_526 = df_6_01_21_n_526.iloc[:, 4:]


df_6_01_21_rb_0   = df_6_01_21_rb_0.iloc[:, 4:]
df_6_01_21_rb_157 = df_6_01_21_rb_157.iloc[:, 4:]
df_6_01_21_rb_280 = df_6_01_21_rb_280.iloc[:, 4:]
df_6_01_21_rb_403 = df_6_01_21_rb_403.iloc[:, 4:]
df_6_01_21_rb_526 = df_6_01_21_rb_526.iloc[:, 4:]

df_6_01_21_no_280 = df_6_01_21_no_280.iloc[:, 4:]
df_6_01_21_no_392 = df_6_01_21_no_392.iloc[:, 4:]
df_6_01_21_no_504 = df_6_01_21_no_504.iloc[:, 4:]
df_6_01_21_no_616 = df_6_01_21_no_616.iloc[:, 4:]


df_6_01_21_alt_34  = df_6_01_21_alt_34.iloc[:, 4:]
df_6_01_21_alt_392 = df_6_01_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_09_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\6_09_2021_LUM_new.xlsx'

df_6_09_21_all = pd.read_excel(LUM_6_09_21, sheet_name='6_09_21_ALL')


# 5_28_20
df_6_09_21_n_0   = df_6_09_21_all[(df_6_09_21_all['N'] == 0)   & (df_6_09_21_all['name'] == 3)]
df_6_09_21_n_157 = df_6_09_21_all[(df_6_09_21_all['N'] == 157) & (df_6_09_21_all['name'] == 3)]
df_6_09_21_n_280 = df_6_09_21_all[(df_6_09_21_all['N'] == 280) & (df_6_09_21_all['name'] == 3)]
df_6_09_21_n_403 = df_6_09_21_all[(df_6_09_21_all['N'] == 403) & (df_6_09_21_all['name'] == 3)]
df_6_09_21_n_526 = df_6_09_21_all[(df_6_09_21_all['N'] == 526) & (df_6_09_21_all['name'] == 3)]


df_6_09_21_rb_0   = df_6_09_21_all[(df_6_09_21_all['N'] == 0)   & (df_6_09_21_all['name'] == 2)]
df_6_09_21_rb_157 = df_6_09_21_all[(df_6_09_21_all['N'] == 157) & (df_6_09_21_all['name'] == 2)]
df_6_09_21_rb_280 = df_6_09_21_all[(df_6_09_21_all['N'] == 280) & (df_6_09_21_all['name'] == 2)]
df_6_09_21_rb_403 = df_6_09_21_all[(df_6_09_21_all['N'] == 403) & (df_6_09_21_all['name'] == 2)]
df_6_09_21_rb_526 = df_6_09_21_all[(df_6_09_21_all['N'] == 526) & (df_6_09_21_all['name'] == 2)]

df_6_09_21_no_280 = df_6_09_21_all[(df_6_09_21_all['N'] == 280) & (df_6_09_21_all['name'] == 1)]
df_6_09_21_no_392 = df_6_09_21_all[(df_6_09_21_all['N'] == 392) & (df_6_09_21_all['name'] == 1)]
df_6_09_21_no_504 = df_6_09_21_all[(df_6_09_21_all['N'] == 504) & (df_6_09_21_all['name'] == 1)]
df_6_09_21_no_616 = df_6_09_21_all[(df_6_09_21_all['N'] == 616) & (df_6_09_21_all['name'] == 1)]


df_6_09_21_alt_34  = df_6_09_21_all[(df_6_09_21_all['N'] == 34)  & (df_6_09_21_all['name'] == 4)]
df_6_09_21_alt_392 = df_6_09_21_all[(df_6_09_21_all['N'] == 392) & (df_6_09_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_6_09_21_n_0   = df_6_09_21_n_0.iloc[:, 4:]
df_6_09_21_n_157 = df_6_09_21_n_157.iloc[:, 4:]
df_6_09_21_n_280 = df_6_09_21_n_280.iloc[:, 4:]
df_6_09_21_n_403 = df_6_09_21_n_403.iloc[:, 4:]
df_6_09_21_n_526 = df_6_09_21_n_526.iloc[:, 4:]


df_6_09_21_rb_0   = df_6_09_21_rb_0.iloc[:, 4:]
df_6_09_21_rb_157 = df_6_09_21_rb_157.iloc[:, 4:]
df_6_09_21_rb_280 = df_6_09_21_rb_280.iloc[:, 4:]
df_6_09_21_rb_403 = df_6_09_21_rb_403.iloc[:, 4:]
df_6_09_21_rb_526 = df_6_09_21_rb_526.iloc[:, 4:]

df_6_09_21_no_280 = df_6_09_21_no_280.iloc[:, 4:]
df_6_09_21_no_392 = df_6_09_21_no_392.iloc[:, 4:]
df_6_09_21_no_504 = df_6_09_21_no_504.iloc[:, 4:]
df_6_09_21_no_616 = df_6_09_21_no_616.iloc[:, 4:]


df_6_09_21_alt_34  = df_6_09_21_alt_34.iloc[:, 4:]
df_6_09_21_alt_392 = df_6_09_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_14_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\6_14_2021_LUM_new.xlsx'

df_6_14_21_all = pd.read_excel(LUM_6_14_21, sheet_name='6_14_21_ALL')


# 5_28_20
df_6_14_21_n_0   = df_6_14_21_all[(df_6_14_21_all['N'] == 0)   & (df_6_14_21_all['name'] == 3)]
df_6_14_21_n_157 = df_6_14_21_all[(df_6_14_21_all['N'] == 157) & (df_6_14_21_all['name'] == 3)]
df_6_14_21_n_280 = df_6_14_21_all[(df_6_14_21_all['N'] == 280) & (df_6_14_21_all['name'] == 3)]
df_6_14_21_n_403 = df_6_14_21_all[(df_6_14_21_all['N'] == 403) & (df_6_14_21_all['name'] == 3)]
df_6_14_21_n_526 = df_6_14_21_all[(df_6_14_21_all['N'] == 526) & (df_6_14_21_all['name'] == 3)]


df_6_14_21_rb_0   = df_6_14_21_all[(df_6_14_21_all['N'] == 0)   & (df_6_14_21_all['name'] == 2)]
df_6_14_21_rb_157 = df_6_14_21_all[(df_6_14_21_all['N'] == 157) & (df_6_14_21_all['name'] == 2)]
df_6_14_21_rb_280 = df_6_14_21_all[(df_6_14_21_all['N'] == 280) & (df_6_14_21_all['name'] == 2)]
df_6_14_21_rb_403 = df_6_14_21_all[(df_6_14_21_all['N'] == 403) & (df_6_14_21_all['name'] == 2)]
df_6_14_21_rb_526 = df_6_14_21_all[(df_6_14_21_all['N'] == 526) & (df_6_14_21_all['name'] == 2)]

df_6_14_21_no_280 = df_6_14_21_all[(df_6_14_21_all['N'] == 280) & (df_6_14_21_all['name'] == 1)]
df_6_14_21_no_392 = df_6_14_21_all[(df_6_14_21_all['N'] == 392) & (df_6_14_21_all['name'] == 1)]
df_6_14_21_no_504 = df_6_14_21_all[(df_6_14_21_all['N'] == 504) & (df_6_14_21_all['name'] == 1)]
df_6_14_21_no_616 = df_6_14_21_all[(df_6_14_21_all['N'] == 616) & (df_6_14_21_all['name'] == 1)]


df_6_14_21_alt_34  = df_6_14_21_all[(df_6_14_21_all['N'] == 34)  & (df_6_14_21_all['name'] == 4)]
df_6_14_21_alt_392 = df_6_14_21_all[(df_6_14_21_all['N'] == 392) & (df_6_14_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_6_14_21_n_0   = df_6_14_21_n_0.iloc[:, 4:]
df_6_14_21_n_157 = df_6_14_21_n_157.iloc[:, 4:]
df_6_14_21_n_280 = df_6_14_21_n_280.iloc[:, 4:]
df_6_14_21_n_403 = df_6_14_21_n_403.iloc[:, 4:]
df_6_14_21_n_526 = df_6_14_21_n_526.iloc[:, 4:]


df_6_14_21_rb_0   = df_6_14_21_rb_0.iloc[:, 4:]
df_6_14_21_rb_157 = df_6_14_21_rb_157.iloc[:, 4:]
df_6_14_21_rb_280 = df_6_14_21_rb_280.iloc[:, 4:]
df_6_14_21_rb_403 = df_6_14_21_rb_403.iloc[:, 4:]
df_6_14_21_rb_526 = df_6_14_21_rb_526.iloc[:, 4:]

df_6_14_21_no_280 = df_6_14_21_no_280.iloc[:, 4:]
df_6_14_21_no_392 = df_6_14_21_no_392.iloc[:, 4:]
df_6_14_21_no_504 = df_6_14_21_no_504.iloc[:, 4:]
df_6_14_21_no_616 = df_6_14_21_no_616.iloc[:, 4:]


df_6_14_21_alt_34  = df_6_14_21_alt_34.iloc[:, 4:]
df_6_14_21_alt_392 = df_6_14_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_23_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\6_23_2021_LUM_new.xlsx'

df_6_23_21_all = pd.read_excel(LUM_6_23_21, sheet_name='6_23_21_ALL')


# 5_28_20
df_6_23_21_n_0   = df_6_23_21_all[(df_6_23_21_all['N'] == 0)   & (df_6_23_21_all['name'] == 3)]
df_6_23_21_n_157 = df_6_23_21_all[(df_6_23_21_all['N'] == 157) & (df_6_23_21_all['name'] == 3)]
df_6_23_21_n_280 = df_6_23_21_all[(df_6_23_21_all['N'] == 280) & (df_6_23_21_all['name'] == 3)]
df_6_23_21_n_403 = df_6_23_21_all[(df_6_23_21_all['N'] == 403) & (df_6_23_21_all['name'] == 3)]
df_6_23_21_n_526 = df_6_23_21_all[(df_6_23_21_all['N'] == 526) & (df_6_23_21_all['name'] == 3)]


df_6_23_21_rb_0   = df_6_23_21_all[(df_6_23_21_all['N'] == 0)   & (df_6_23_21_all['name'] == 2)]
df_6_23_21_rb_157 = df_6_23_21_all[(df_6_23_21_all['N'] == 157) & (df_6_23_21_all['name'] == 2)]
df_6_23_21_rb_280 = df_6_23_21_all[(df_6_23_21_all['N'] == 280) & (df_6_23_21_all['name'] == 2)]
df_6_23_21_rb_403 = df_6_23_21_all[(df_6_23_21_all['N'] == 403) & (df_6_23_21_all['name'] == 2)]
df_6_23_21_rb_526 = df_6_23_21_all[(df_6_23_21_all['N'] == 526) & (df_6_23_21_all['name'] == 2)]

df_6_23_21_no_280 = df_6_23_21_all[(df_6_23_21_all['N'] == 280) & (df_6_23_21_all['name'] == 1)]
df_6_23_21_no_392 = df_6_23_21_all[(df_6_23_21_all['N'] == 392) & (df_6_23_21_all['name'] == 1)]
df_6_23_21_no_504 = df_6_23_21_all[(df_6_23_21_all['N'] == 504) & (df_6_23_21_all['name'] == 1)]
df_6_23_21_no_616 = df_6_23_21_all[(df_6_23_21_all['N'] == 616) & (df_6_23_21_all['name'] == 1)]


df_6_23_21_alt_34  = df_6_23_21_all[(df_6_23_21_all['N'] == 34)  & (df_6_23_21_all['name'] == 4)]
df_6_23_21_alt_392 = df_6_23_21_all[(df_6_23_21_all['N'] == 392) & (df_6_23_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_6_23_21_n_0   = df_6_23_21_n_0.iloc[:, 4:]
df_6_23_21_n_157 = df_6_23_21_n_157.iloc[:, 4:]
df_6_23_21_n_280 = df_6_23_21_n_280.iloc[:, 4:]
df_6_23_21_n_403 = df_6_23_21_n_403.iloc[:, 4:]
df_6_23_21_n_526 = df_6_23_21_n_526.iloc[:, 4:]


df_6_23_21_rb_0   = df_6_23_21_rb_0.iloc[:, 4:]
df_6_23_21_rb_157 = df_6_23_21_rb_157.iloc[:, 4:]
df_6_23_21_rb_280 = df_6_23_21_rb_280.iloc[:, 4:]
df_6_23_21_rb_403 = df_6_23_21_rb_403.iloc[:, 4:]
df_6_23_21_rb_526 = df_6_23_21_rb_526.iloc[:, 4:]

df_6_23_21_no_280 = df_6_23_21_no_280.iloc[:, 4:]
df_6_23_21_no_392 = df_6_23_21_no_392.iloc[:, 4:]
df_6_23_21_no_504 = df_6_23_21_no_504.iloc[:, 4:]
df_6_23_21_no_616 = df_6_23_21_no_616.iloc[:, 4:]


df_6_23_21_alt_34  = df_6_23_21_alt_34.iloc[:, 4:]
df_6_23_21_alt_392 = df_6_23_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_14_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\7_14_2021_LUM_new.xlsx'

df_7_14_21_all = pd.read_excel(LUM_7_14_21, sheet_name='7_14_21_ALL')


# 5_28_20
df_7_14_21_n_0   = df_7_14_21_all[(df_7_14_21_all['N'] == 0)   & (df_7_14_21_all['name'] == 3)]
df_7_14_21_n_157 = df_7_14_21_all[(df_7_14_21_all['N'] == 157) & (df_7_14_21_all['name'] == 3)]
df_7_14_21_n_280 = df_7_14_21_all[(df_7_14_21_all['N'] == 280) & (df_7_14_21_all['name'] == 3)]
df_7_14_21_n_403 = df_7_14_21_all[(df_7_14_21_all['N'] == 403) & (df_7_14_21_all['name'] == 3)]
df_7_14_21_n_526 = df_7_14_21_all[(df_7_14_21_all['N'] == 526) & (df_7_14_21_all['name'] == 3)]


df_7_14_21_rb_0   = df_7_14_21_all[(df_7_14_21_all['N'] == 0)   & (df_7_14_21_all['name'] == 2)]
df_7_14_21_rb_157 = df_7_14_21_all[(df_7_14_21_all['N'] == 157) & (df_7_14_21_all['name'] == 2)]
df_7_14_21_rb_280 = df_7_14_21_all[(df_7_14_21_all['N'] == 280) & (df_7_14_21_all['name'] == 2)]
df_7_14_21_rb_403 = df_7_14_21_all[(df_7_14_21_all['N'] == 403) & (df_7_14_21_all['name'] == 2)]
df_7_14_21_rb_526 = df_7_14_21_all[(df_7_14_21_all['N'] == 526) & (df_7_14_21_all['name'] == 2)]

df_7_14_21_no_280 = df_7_14_21_all[(df_7_14_21_all['N'] == 280) & (df_7_14_21_all['name'] == 1)]
df_7_14_21_no_392 = df_7_14_21_all[(df_7_14_21_all['N'] == 392) & (df_7_14_21_all['name'] == 1)]
df_7_14_21_no_504 = df_7_14_21_all[(df_7_14_21_all['N'] == 504) & (df_7_14_21_all['name'] == 1)]
df_7_14_21_no_616 = df_7_14_21_all[(df_7_14_21_all['N'] == 616) & (df_7_14_21_all['name'] == 1)]


df_7_14_21_alt_34  = df_7_14_21_all[(df_7_14_21_all['N'] == 34)  & (df_7_14_21_all['name'] == 4)]
df_7_14_21_alt_392 = df_7_14_21_all[(df_7_14_21_all['N'] == 392) & (df_7_14_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_7_14_21_n_0   = df_7_14_21_n_0.iloc[:, 4:]
df_7_14_21_n_157 = df_7_14_21_n_157.iloc[:, 4:]
df_7_14_21_n_280 = df_7_14_21_n_280.iloc[:, 4:]
df_7_14_21_n_403 = df_7_14_21_n_403.iloc[:, 4:]
df_7_14_21_n_526 = df_7_14_21_n_526.iloc[:, 4:]


df_7_14_21_rb_0   = df_7_14_21_rb_0.iloc[:, 4:]
df_7_14_21_rb_157 = df_7_14_21_rb_157.iloc[:, 4:]
df_7_14_21_rb_280 = df_7_14_21_rb_280.iloc[:, 4:]
df_7_14_21_rb_403 = df_7_14_21_rb_403.iloc[:, 4:]
df_7_14_21_rb_526 = df_7_14_21_rb_526.iloc[:, 4:]

df_7_14_21_no_280 = df_7_14_21_no_280.iloc[:, 4:]
df_7_14_21_no_392 = df_7_14_21_no_392.iloc[:, 4:]
df_7_14_21_no_504 = df_7_14_21_no_504.iloc[:, 4:]
df_7_14_21_no_616 = df_7_14_21_no_616.iloc[:, 4:]


df_7_14_21_alt_34  = df_7_14_21_alt_34.iloc[:, 4:]
df_7_14_21_alt_392 = df_7_14_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_23_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\7_23_2021_LUM_new.xlsx'

df_7_23_21_all = pd.read_excel(LUM_7_23_21, sheet_name='7_23_21_ALL')


# 5_28_20
df_7_23_21_n_0   = df_7_23_21_all[(df_7_23_21_all['N'] == 0)   & (df_7_23_21_all['name'] == 3)]
df_7_23_21_n_157 = df_7_23_21_all[(df_7_23_21_all['N'] == 157) & (df_7_23_21_all['name'] == 3)]
df_7_23_21_n_280 = df_7_23_21_all[(df_7_23_21_all['N'] == 280) & (df_7_23_21_all['name'] == 3)]
df_7_23_21_n_403 = df_7_23_21_all[(df_7_23_21_all['N'] == 403) & (df_7_23_21_all['name'] == 3)]
df_7_23_21_n_526 = df_7_23_21_all[(df_7_23_21_all['N'] == 526) & (df_7_23_21_all['name'] == 3)]


df_7_23_21_rb_0   = df_7_23_21_all[(df_7_23_21_all['N'] == 0)   & (df_7_23_21_all['name'] == 2)]
df_7_23_21_rb_157 = df_7_23_21_all[(df_7_23_21_all['N'] == 157) & (df_7_23_21_all['name'] == 2)]
df_7_23_21_rb_280 = df_7_23_21_all[(df_7_23_21_all['N'] == 280) & (df_7_23_21_all['name'] == 2)]
df_7_23_21_rb_403 = df_7_23_21_all[(df_7_23_21_all['N'] == 403) & (df_7_23_21_all['name'] == 2)]
df_7_23_21_rb_526 = df_7_23_21_all[(df_7_23_21_all['N'] == 526) & (df_7_23_21_all['name'] == 2)]

df_7_23_21_no_280 = df_7_23_21_all[(df_7_23_21_all['N'] == 280) & (df_7_23_21_all['name'] == 1)]
df_7_23_21_no_392 = df_7_23_21_all[(df_7_23_21_all['N'] == 392) & (df_7_23_21_all['name'] == 1)]
df_7_23_21_no_504 = df_7_23_21_all[(df_7_23_21_all['N'] == 504) & (df_7_23_21_all['name'] == 1)]
df_7_23_21_no_616 = df_7_23_21_all[(df_7_23_21_all['N'] == 616) & (df_7_23_21_all['name'] == 1)]


df_7_23_21_alt_34  = df_7_23_21_all[(df_7_23_21_all['N'] == 34)  & (df_7_23_21_all['name'] == 4)]
df_7_23_21_alt_392 = df_7_23_21_all[(df_7_23_21_all['N'] == 392) & (df_7_23_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_7_23_21_n_0   = df_7_23_21_n_0.iloc[:, 4:]
df_7_23_21_n_157 = df_7_23_21_n_157.iloc[:, 4:]
df_7_23_21_n_280 = df_7_23_21_n_280.iloc[:, 4:]
df_7_23_21_n_403 = df_7_23_21_n_403.iloc[:, 4:]
df_7_23_21_n_526 = df_7_23_21_n_526.iloc[:, 4:]


df_7_23_21_rb_0   = df_7_23_21_rb_0.iloc[:, 4:]
df_7_23_21_rb_157 = df_7_23_21_rb_157.iloc[:, 4:]
df_7_23_21_rb_280 = df_7_23_21_rb_280.iloc[:, 4:]
df_7_23_21_rb_403 = df_7_23_21_rb_403.iloc[:, 4:]
df_7_23_21_rb_526 = df_7_23_21_rb_526.iloc[:, 4:]

df_7_23_21_no_280 = df_7_23_21_no_280.iloc[:, 4:]
df_7_23_21_no_392 = df_7_23_21_no_392.iloc[:, 4:]
df_7_23_21_no_504 = df_7_23_21_no_504.iloc[:, 4:]
df_7_23_21_no_616 = df_7_23_21_no_616.iloc[:, 4:]


df_7_23_21_alt_34  = df_7_23_21_alt_34.iloc[:, 4:]
df_7_23_21_alt_392 = df_7_23_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_30_21 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2021\7_30_2021_LUM_new.xlsx'

df_7_30_21_all = pd.read_excel(LUM_7_30_21, sheet_name='7_30_21_ALL')


# 5_28_20
df_7_30_21_n_0   = df_7_30_21_all[(df_7_30_21_all['N'] == 0)   & (df_7_30_21_all['name'] == 3)]
df_7_30_21_n_157 = df_7_30_21_all[(df_7_30_21_all['N'] == 157) & (df_7_30_21_all['name'] == 3)]
df_7_30_21_n_280 = df_7_30_21_all[(df_7_30_21_all['N'] == 280) & (df_7_30_21_all['name'] == 3)]
df_7_30_21_n_403 = df_7_30_21_all[(df_7_30_21_all['N'] == 403) & (df_7_30_21_all['name'] == 3)]
df_7_30_21_n_526 = df_7_30_21_all[(df_7_30_21_all['N'] == 526) & (df_7_30_21_all['name'] == 3)]


df_7_30_21_rb_0   = df_7_30_21_all[(df_7_30_21_all['N'] == 0)   & (df_7_30_21_all['name'] == 2)]
df_7_30_21_rb_157 = df_7_30_21_all[(df_7_30_21_all['N'] == 157) & (df_7_30_21_all['name'] == 2)]
df_7_30_21_rb_280 = df_7_30_21_all[(df_7_30_21_all['N'] == 280) & (df_7_30_21_all['name'] == 2)]
df_7_30_21_rb_403 = df_7_30_21_all[(df_7_30_21_all['N'] == 403) & (df_7_30_21_all['name'] == 2)]
df_7_30_21_rb_526 = df_7_30_21_all[(df_7_30_21_all['N'] == 526) & (df_7_30_21_all['name'] == 2)]

df_7_30_21_no_280 = df_7_30_21_all[(df_7_30_21_all['N'] == 280) & (df_7_30_21_all['name'] == 1)]
df_7_30_21_no_392 = df_7_30_21_all[(df_7_30_21_all['N'] == 392) & (df_7_30_21_all['name'] == 1)]
df_7_30_21_no_504 = df_7_30_21_all[(df_7_30_21_all['N'] == 504) & (df_7_30_21_all['name'] == 1)]
df_7_30_21_no_616 = df_7_30_21_all[(df_7_30_21_all['N'] == 616) & (df_7_30_21_all['name'] == 1)]


df_7_30_21_alt_34  = df_7_30_21_all[(df_7_30_21_all['N'] == 34)  & (df_7_30_21_all['name'] == 4)]
df_7_30_21_alt_392 = df_7_30_21_all[(df_7_30_21_all['N'] == 392) & (df_7_30_21_all['name'] == 4)]


# remove first four column
# 5_28_20
df_7_30_21_n_0   = df_7_30_21_n_0.iloc[:, 4:]
df_7_30_21_n_157 = df_7_30_21_n_157.iloc[:, 4:]
df_7_30_21_n_280 = df_7_30_21_n_280.iloc[:, 4:]
df_7_30_21_n_403 = df_7_30_21_n_403.iloc[:, 4:]
df_7_30_21_n_526 = df_7_30_21_n_526.iloc[:, 4:]


df_7_30_21_rb_0   = df_7_30_21_rb_0.iloc[:, 4:]
df_7_30_21_rb_157 = df_7_30_21_rb_157.iloc[:, 4:]
df_7_30_21_rb_280 = df_7_30_21_rb_280.iloc[:, 4:]
df_7_30_21_rb_403 = df_7_30_21_rb_403.iloc[:, 4:]
df_7_30_21_rb_526 = df_7_30_21_rb_526.iloc[:, 4:]

df_7_30_21_no_280 = df_7_30_21_no_280.iloc[:, 4:]
df_7_30_21_no_392 = df_7_30_21_no_392.iloc[:, 4:]
df_7_30_21_no_504 = df_7_30_21_no_504.iloc[:, 4:]
df_7_30_21_no_616 = df_7_30_21_no_616.iloc[:, 4:]


df_7_30_21_alt_34  = df_7_30_21_alt_34.iloc[:, 4:]
df_7_30_21_alt_392 = df_7_30_21_alt_392.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

#variable_names = ['SR','VF']
#variable_names = ['NDVI','GNDVI','DVI','EVI','EVI2','MARI','CHLRE','CHLGR','SAVI','SAVI2']

variable_names = ['MSAVI','OSAVI','TSAVI','MSR','MCARI','MCARI/OSAVI','PVI','SR','WDRI','VF']
# Calculate the number of rows and columns needed based on the number of variables
num_variables = len(variable_names)
num_rows = math.ceil(num_variables / 1)  # Each row contains 1 variable
num_cols = 5  # Two columns for two dates

# Create subplots for each variable in two columns
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(11, 2.5 * num_variables), sharey='row')

for i, var in enumerate(variable_names):
    # Plot for date 5_28 (left column)
    ax1 = axes[i, 0]
    
    box_color_new = '#FFB6C1'
    box_color_rb = '#ADD8E6'
    box_color_nork = '#90EE90'
    box_color_alt = '#F0E68C'  # khaki color
    
    # Define data for each nitrogen level and variety
    df_5_26_new = [df_5_26_21_n_0[var],
                   df_5_26_21_n_157[var],
                   df_5_26_21_n_280[var],
                   df_5_26_21_n_403[var],
                   df_5_26_21_n_526[var]]
    
    df_5_26_rb = [df_5_26_21_rb_0[var],
                  df_5_26_21_rb_157[var],
                  df_5_26_21_rb_280[var],
                  df_5_26_21_rb_403[var],
                  df_5_26_21_rb_526[var]]

    df_5_26_nork = [df_5_26_21_no_280[var],
                    df_5_26_21_no_392[var],
                    df_5_26_21_no_504[var],
                    df_5_26_21_no_616[var]]

    
    df_5_26_alt = [df_5_26_21_alt_34[var],
                   df_5_26_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax1.boxplot(df_5_26_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax1.boxplot(df_5_26_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax1.boxplot(df_5_26_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax1.boxplot(df_5_26_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)

    ax1.set_xticks([1.1, 2, 3, 4.2, 5.1, 6, 7, 8.1, 9])
    ax1.set_xticklabels(['0', '34', '157', '280', '392','403','504', '526', '616'], rotation=90,fontsize=8)
    ax1.set_ylabel(var, fontsize=8)


    if i == num_variables - 1:
        ax1.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax1.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax1.set_xticks([])

    if i == 0:
        ax1.set_title('T1: Emergence', fontsize=10)

    ax1.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax1.tick_params(axis='y', labelsize=10)



 # Plot for date 6_03 (right column)
    ax2 = axes[i, 1]
    # Define data for each nitrogen level and variety
    df_6_01_new = [df_6_01_21_n_0[var],
                   df_6_01_21_n_157[var],
                   df_6_01_21_n_280[var],
                   df_6_01_21_n_403[var],
                   df_6_01_21_n_526[var]]
    
    df_6_01_rb = [df_6_01_21_rb_0[var],
                  df_6_01_21_rb_157[var],
                  df_6_01_21_rb_280[var],
                  df_6_01_21_rb_403[var],
                  df_6_01_21_rb_526[var]]

    df_6_01_nork = [df_6_01_21_no_280[var],
                    df_6_01_21_no_392[var],
                    df_6_01_21_no_504[var],
                    df_6_01_21_no_616[var]]

    
    df_6_01_alt = [df_6_01_21_alt_34[var],
                   df_6_01_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax2.boxplot(df_6_01_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax2.boxplot(df_6_01_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax2.boxplot(df_6_01_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax2.boxplot(df_6_01_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    # Define data for each nitrogen level and variety
    df_6_09_new = [df_6_09_21_n_0[var],
                   df_6_09_21_n_157[var],
                   df_6_09_21_n_280[var],
                   df_6_09_21_n_403[var],
                   df_6_09_21_n_526[var]]
    
    df_6_09_rb = [df_6_09_21_rb_0[var],
                  df_6_09_21_rb_157[var],
                  df_6_09_21_rb_280[var],
                  df_6_09_21_rb_403[var],
                  df_6_09_21_rb_526[var]]

    df_6_09_nork = [df_6_09_21_no_280[var],
                    df_6_09_21_no_392[var],
                    df_6_09_21_no_504[var],
                    df_6_09_21_no_616[var]]

    
    df_6_09_alt = [df_6_09_21_alt_34[var],
                   df_6_09_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax2.boxplot(df_6_09_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax2.boxplot(df_6_09_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax2.boxplot(df_6_09_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax2.boxplot(df_6_09_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    ax2.set_xticks([1.1, 2, 3, 4.2, 5.1, 6, 7, 8.1, 9])
    ax2.set_xticklabels(['0', '34', '157', '280', '392','403','504', '526', '616'], rotation=90,fontsize=8)
    if i == num_variables - 1:
        ax2.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax2.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax2.set_xticks([])

    if i == 0:
        ax2.set_title('T2: Vegetative', fontsize=10)

    ax2.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax2.tick_params(axis='y', labelsize=10)

# Plot for date 6_03 (right column)
    ax3 = axes[i, 2]

    # Define data for each nitrogen level and variety
    df_6_14_new = [df_6_14_21_n_0[var],
                   df_6_14_21_n_157[var],
                   df_6_14_21_n_280[var],
                   df_6_14_21_n_403[var],
                   df_6_14_21_n_526[var]]
    
    df_6_14_rb = [df_6_14_21_rb_0[var],
                  df_6_14_21_rb_157[var],
                  df_6_14_21_rb_280[var],
                  df_6_14_21_rb_403[var],
                  df_6_14_21_rb_526[var]]

    df_6_14_nork = [df_6_14_21_no_280[var],
                    df_6_14_21_no_392[var],
                    df_6_14_21_no_504[var],
                    df_6_14_21_no_616[var]]

    
    df_6_14_alt = [df_6_14_21_alt_34[var],
                   df_6_14_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax3.boxplot(df_6_14_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax3.boxplot(df_6_14_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax3.boxplot(df_6_14_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax3.boxplot(df_6_14_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    # Define data for each nitrogen level and variety
    df_6_23_new = [df_6_23_21_n_0[var],
                   df_6_23_21_n_157[var],
                   df_6_23_21_n_280[var],
                   df_6_23_21_n_403[var],
                   df_6_23_21_n_526[var]]
    
    df_6_23_rb = [df_6_23_21_rb_0[var],
                  df_6_23_21_rb_157[var],
                  df_6_23_21_rb_280[var],
                  df_6_23_21_rb_403[var],
                  df_6_23_21_rb_526[var]]

    df_6_23_nork = [df_6_23_21_no_280[var],
                    df_6_23_21_no_392[var],
                    df_6_23_21_no_504[var],
                    df_6_23_21_no_616[var]]

    
    df_6_23_alt = [df_6_23_21_alt_34[var],
                   df_6_23_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax3.boxplot(df_6_23_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax3.boxplot(df_6_23_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax3.boxplot(df_6_23_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax3.boxplot(df_6_23_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    
    ax3.set_xticks([1.1, 2, 3, 4.2, 5.1, 6, 7, 8.1, 9])
    ax3.set_xticklabels(['0', '34', '157', '280', '392','403','504', '526', '616'], rotation=90,fontsize=8)
    if i == num_variables - 1:
        ax3.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax3.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax3.set_xticks([])

    if i == 0:
        ax3.set_title('T3: Tuberization', fontsize=10)

    ax3.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax3.tick_params(axis='y', labelsize=10)


    # Plot for date 6_03 (right column)
    ax4 = axes[i, 3]
    
    # Define data for each nitrogen level and variety
    df_7_14_new = [df_7_14_21_n_0[var],
                   df_7_14_21_n_157[var],
                   df_7_14_21_n_280[var],
                   df_7_14_21_n_403[var],
                   df_7_14_21_n_526[var]]
    
    df_7_14_rb = [df_7_14_21_rb_0[var],
                  df_7_14_21_rb_157[var],
                  df_7_14_21_rb_280[var],
                  df_7_14_21_rb_403[var],
                  df_7_14_21_rb_526[var]]

    df_7_14_nork = [df_7_14_21_no_280[var],
                    df_7_14_21_no_392[var],
                    df_7_14_21_no_504[var],
                    df_7_14_21_no_616[var]]

    
    df_7_14_alt = [df_7_14_21_alt_34[var],
                   df_7_14_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax4.boxplot(df_7_14_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax4.boxplot(df_7_14_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax4.boxplot(df_7_14_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax4.boxplot(df_7_14_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    df_7_23_new = [df_7_23_21_n_0[var],
                   df_7_23_21_n_157[var],
                   df_7_23_21_n_280[var],
                   df_7_23_21_n_403[var],
                   df_7_23_21_n_526[var]]
    
    df_7_23_rb = [df_7_23_21_rb_0[var],
                  df_7_23_21_rb_157[var],
                  df_7_23_21_rb_280[var],
                  df_7_23_21_rb_403[var],
                  df_7_23_21_rb_526[var]]

    df_7_23_nork = [df_7_23_21_no_280[var],
                    df_7_23_21_no_392[var],
                    df_7_23_21_no_504[var],
                    df_7_23_21_no_616[var]]

    
    df_7_23_alt = [df_7_23_21_alt_34[var],
                   df_7_23_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax4.boxplot(df_7_23_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax4.boxplot(df_7_23_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax4.boxplot(df_7_23_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax4.boxplot(df_7_23_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)




    ax4.set_xticks([1.1, 2, 3, 4.2, 5.1, 6, 7, 8.1, 9])
    ax4.set_xticklabels(['0', '34', '157', '280', '392','403','504', '526', '616'], rotation=90,fontsize=8)
    if i == num_variables - 1:
        ax4.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax4.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax4.set_xticks([])

    if i == 0:
        ax4.set_title('T4: Bulking', fontsize=10)

    ax4.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax4.tick_params(axis='y', labelsize=10)



  # Plot for date 6_03 (right column)
    ax5 = axes[i, 4]
    
    # Define data for each nitrogen level and variety
    df_7_34_new = [df_7_30_21_n_0[var],
                   df_7_30_21_n_157[var],
                   df_7_30_21_n_280[var],
                   df_7_30_21_n_403[var],
                   df_7_30_21_n_526[var]]
    
    df_7_34_rb = [df_7_30_21_rb_0[var],
                  df_7_30_21_rb_157[var],
                  df_7_30_21_rb_280[var],
                  df_7_30_21_rb_403[var],
                  df_7_30_21_rb_526[var]]

    df_7_34_nork = [df_7_30_21_no_280[var],
                    df_7_30_21_no_392[var],
                    df_7_30_21_no_504[var],
                    df_7_30_21_no_616[var]]

    
    df_7_34_alt = [df_7_30_21_alt_34[var],
                   df_7_30_21_alt_392[var]]
    
    # Plot box plots for each set of data
    ax5.boxplot(df_7_34_new, 
                              widths=0.15, 
                              positions=[1, 3, 4, 6, 8], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)
    
    ax5.boxplot(df_7_34_nork, 
                               widths=0.15, 
                               positions=[4.2, 5.2, 7, 9],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    ax5.boxplot(df_7_34_rb, 
                             widths=0.15, 
                             positions=[1.2, 3.2, 4.4, 6.2, 8.2],  # Adjust positions for different nitrogen values
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    
    ax5.boxplot(df_7_34_alt, 
                               widths=0.15, 
                               positions=[2, 5],  # Adjust positions for different nitrogen values
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_alt, color=box_color_alt),
                               whiskerprops=dict(color=box_color_alt, linestyle='-'),
                               capprops=dict(color=box_color_alt),
                               flierprops=dict(markerfacecolor=box_color_alt, markeredgecolor='darkgoldenrod', markersize=5),
                               medianprops=dict(color='darkgoldenrod'),showfliers=False)
    
    ax5.set_xticks([1.1, 2, 3, 4.2, 5.1, 6, 7, 8.1, 9])
    ax5.set_xticklabels(['0', '34', '157', '280', '392','403','504', '526', '616'], rotation=90, fontsize=8)
    if i == num_variables - 1:
        ax5.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax5.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax5.set_xticks([])

    if i == 0:
        ax5.set_title('T5: Maturity', fontsize=10)

    ax5.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax5.tick_params(axis='y', labelsize=10)
    
    
    
    

    
# Adjust layout to include legend
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.subplots_adjust(hspace=0.09, wspace=0.09)
plt.savefig('C:/Users/Say70/OneDrive - Mississippi State University/Desktop/Yield monitoring_new/2021_2_all.png', dpi=1000, bbox_inches='tight')

plt.show()
