# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_5_28_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\5_28_2020_LUM_new.xlsx'

df_5_28_20_all = pd.read_excel(LUM_5_28_20, sheet_name='5_28_20_ALL')

# 5_28_20
df_5_28_20_n_275 = df_5_28_20_all[(df_5_28_20_all['N'] == 275) & (df_5_28_20_all['name'] == 3)]
df_5_28_20_n_387 = df_5_28_20_all[(df_5_28_20_all['N'] == 387) & (df_5_28_20_all['name'] == 3)]
df_5_28_20_n_513 = df_5_28_20_all[(df_5_28_20_all['N'] == 513) & (df_5_28_20_all['name'] == 3)]
df_5_28_20_n_639 = df_5_28_20_all[(df_5_28_20_all['N'] == 639) & (df_5_28_20_all['name'] == 3)]

df_5_28_20_no_275 = df_5_28_20_all[(df_5_28_20_all['N'] == 275) & (df_5_28_20_all['name'] == 1)]
df_5_28_20_no_387 = df_5_28_20_all[(df_5_28_20_all['N'] == 387) & (df_5_28_20_all['name'] == 1)]
df_5_28_20_no_513 = df_5_28_20_all[(df_5_28_20_all['N'] == 513) & (df_5_28_20_all['name'] == 1)]
df_5_28_20_no_639 = df_5_28_20_all[(df_5_28_20_all['N'] == 639) & (df_5_28_20_all['name'] == 1)]

df_5_28_20_rb_275 = df_5_28_20_all[(df_5_28_20_all['N'] == 275) & (df_5_28_20_all['name'] == 2)]
df_5_28_20_rb_387 = df_5_28_20_all[(df_5_28_20_all['N'] == 387) & (df_5_28_20_all['name'] == 2)]
df_5_28_20_rb_513 = df_5_28_20_all[(df_5_28_20_all['N'] == 513) & (df_5_28_20_all['name'] == 2)]
df_5_28_20_rb_639 = df_5_28_20_all[(df_5_28_20_all['N'] == 639) & (df_5_28_20_all['name'] == 2)]

# remove first four column
df_5_28_20_n_275 = df_5_28_20_n_275.iloc[:, 4:]
df_5_28_20_n_387 = df_5_28_20_n_387.iloc[:, 4:]
df_5_28_20_n_513 = df_5_28_20_n_513.iloc[:, 4:]
df_5_28_20_n_639 = df_5_28_20_n_639.iloc[:, 4:]
df_5_28_20_no_275 = df_5_28_20_no_275.iloc[:, 4:]
df_5_28_20_no_387 = df_5_28_20_no_387.iloc[:, 4:]
df_5_28_20_no_513 = df_5_28_20_no_513.iloc[:, 4:]
df_5_28_20_no_639 = df_5_28_20_no_639.iloc[:, 4:]
df_5_28_20_rb_275 = df_5_28_20_rb_275.iloc[:, 4:]
df_5_28_20_rb_387 = df_5_28_20_rb_387.iloc[:, 4:]
df_5_28_20_rb_513 = df_5_28_20_rb_513.iloc[:, 4:]
df_5_28_20_rb_639 = df_5_28_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_03_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\6_03_2020_LUM_new.xlsx'

df_6_03_20_all = pd.read_excel(LUM_6_03_20, sheet_name='6_03_20_ALL')

# 6_03_20
df_6_03_20_n_275 = df_6_03_20_all[(df_6_03_20_all['N'] == 275) & (df_6_03_20_all['name'] == 3)]
df_6_03_20_n_387 = df_6_03_20_all[(df_6_03_20_all['N'] == 387) & (df_6_03_20_all['name'] == 3)]
df_6_03_20_n_513 = df_6_03_20_all[(df_6_03_20_all['N'] == 513) & (df_6_03_20_all['name'] == 3)]
df_6_03_20_n_639 = df_6_03_20_all[(df_6_03_20_all['N'] == 639) & (df_6_03_20_all['name'] == 3)]

df_6_03_20_no_275 = df_6_03_20_all[(df_6_03_20_all['N'] == 275) & (df_6_03_20_all['name'] == 1)]
df_6_03_20_no_387 = df_6_03_20_all[(df_6_03_20_all['N'] == 387) & (df_6_03_20_all['name'] == 1)]
df_6_03_20_no_513 = df_6_03_20_all[(df_6_03_20_all['N'] == 513) & (df_6_03_20_all['name'] == 1)]
df_6_03_20_no_639 = df_6_03_20_all[(df_6_03_20_all['N'] == 639) & (df_6_03_20_all['name'] == 1)]

df_6_03_20_rb_275 = df_6_03_20_all[(df_6_03_20_all['N'] == 275) & (df_6_03_20_all['name'] == 2)]
df_6_03_20_rb_387 = df_6_03_20_all[(df_6_03_20_all['N'] == 387) & (df_6_03_20_all['name'] == 2)]
df_6_03_20_rb_513 = df_6_03_20_all[(df_6_03_20_all['N'] == 513) & (df_6_03_20_all['name'] == 2)]
df_6_03_20_rb_639 = df_6_03_20_all[(df_6_03_20_all['N'] == 639) & (df_6_03_20_all['name'] == 2)]

# remove first four column
df_6_03_20_n_275 = df_6_03_20_n_275.iloc[:, 4:]
df_6_03_20_n_387 = df_6_03_20_n_387.iloc[:, 4:]
df_6_03_20_n_513 = df_6_03_20_n_513.iloc[:, 4:]
df_6_03_20_n_639 = df_6_03_20_n_639.iloc[:, 4:]
df_6_03_20_no_275 = df_6_03_20_no_275.iloc[:, 4:]
df_6_03_20_no_387 = df_6_03_20_no_387.iloc[:, 4:]
df_6_03_20_no_513 = df_6_03_20_no_513.iloc[:, 4:]
df_6_03_20_no_639 = df_6_03_20_no_639.iloc[:, 4:]
df_6_03_20_rb_275 = df_6_03_20_rb_275.iloc[:, 4:]
df_6_03_20_rb_387 = df_6_03_20_rb_387.iloc[:, 4:]
df_6_03_20_rb_513 = df_6_03_20_rb_513.iloc[:, 4:]
df_6_03_20_rb_639 = df_6_03_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_10_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\6_10_2020_LUM_new.xlsx'

df_6_10_20_all = pd.read_excel(LUM_6_10_20, sheet_name='6_10_20_ALL')

# 6_10_20
df_6_10_20_n_275 = df_6_10_20_all[(df_6_10_20_all['N'] == 275) & (df_6_10_20_all['name'] == 3)]
df_6_10_20_n_387 = df_6_10_20_all[(df_6_10_20_all['N'] == 387) & (df_6_10_20_all['name'] == 3)]
df_6_10_20_n_513 = df_6_10_20_all[(df_6_10_20_all['N'] == 513) & (df_6_10_20_all['name'] == 3)]
df_6_10_20_n_639 = df_6_10_20_all[(df_6_10_20_all['N'] == 639) & (df_6_10_20_all['name'] == 3)]

df_6_10_20_no_275 = df_6_10_20_all[(df_6_10_20_all['N'] == 275) & (df_6_10_20_all['name'] == 1)]
df_6_10_20_no_387 = df_6_10_20_all[(df_6_10_20_all['N'] == 387) & (df_6_10_20_all['name'] == 1)]
df_6_10_20_no_513 = df_6_10_20_all[(df_6_10_20_all['N'] == 513) & (df_6_10_20_all['name'] == 1)]
df_6_10_20_no_639 = df_6_10_20_all[(df_6_10_20_all['N'] == 639) & (df_6_10_20_all['name'] == 1)]

df_6_10_20_rb_275 = df_6_10_20_all[(df_6_10_20_all['N'] == 275) & (df_6_10_20_all['name'] == 2)]
df_6_10_20_rb_387 = df_6_10_20_all[(df_6_10_20_all['N'] == 387) & (df_6_10_20_all['name'] == 2)]
df_6_10_20_rb_513 = df_6_10_20_all[(df_6_10_20_all['N'] == 513) & (df_6_10_20_all['name'] == 2)]
df_6_10_20_rb_639 = df_6_10_20_all[(df_6_10_20_all['N'] == 639) & (df_6_10_20_all['name'] == 2)]

# remove first four column
df_6_10_20_n_275 = df_6_10_20_n_275.iloc[:, 4:]
df_6_10_20_n_387 = df_6_10_20_n_387.iloc[:, 4:]
df_6_10_20_n_513 = df_6_10_20_n_513.iloc[:, 4:]
df_6_10_20_n_639 = df_6_10_20_n_639.iloc[:, 4:]
df_6_10_20_no_275 = df_6_10_20_no_275.iloc[:, 4:]
df_6_10_20_no_387 = df_6_10_20_no_387.iloc[:, 4:]
df_6_10_20_no_513 = df_6_10_20_no_513.iloc[:, 4:]
df_6_10_20_no_639 = df_6_10_20_no_639.iloc[:, 4:]
df_6_10_20_rb_275 = df_6_10_20_rb_275.iloc[:, 4:]
df_6_10_20_rb_387 = df_6_10_20_rb_387.iloc[:, 4:]
df_6_10_20_rb_513 = df_6_10_20_rb_513.iloc[:, 4:]
df_6_10_20_rb_639 = df_6_10_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_15_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\6_15_2020_LUM_new.xlsx'

df_6_15_20_all = pd.read_excel(LUM_6_15_20, sheet_name='6_15_20_ALL')

# 6_15_20
df_6_15_20_n_275 = df_6_15_20_all[(df_6_15_20_all['N'] == 275) & (df_6_15_20_all['name'] == 3)]
df_6_15_20_n_387 = df_6_15_20_all[(df_6_15_20_all['N'] == 387) & (df_6_15_20_all['name'] == 3)]
df_6_15_20_n_513 = df_6_15_20_all[(df_6_15_20_all['N'] == 513) & (df_6_15_20_all['name'] == 3)]
df_6_15_20_n_639 = df_6_15_20_all[(df_6_15_20_all['N'] == 639) & (df_6_15_20_all['name'] == 3)]

df_6_15_20_no_275 = df_6_15_20_all[(df_6_15_20_all['N'] == 275) & (df_6_15_20_all['name'] == 1)]
df_6_15_20_no_387 = df_6_15_20_all[(df_6_15_20_all['N'] == 387) & (df_6_15_20_all['name'] == 1)]
df_6_15_20_no_513 = df_6_15_20_all[(df_6_15_20_all['N'] == 513) & (df_6_15_20_all['name'] == 1)]
df_6_15_20_no_639 = df_6_15_20_all[(df_6_15_20_all['N'] == 639) & (df_6_15_20_all['name'] == 1)]

df_6_15_20_rb_275 = df_6_15_20_all[(df_6_15_20_all['N'] == 275) & (df_6_15_20_all['name'] == 2)]
df_6_15_20_rb_387 = df_6_15_20_all[(df_6_15_20_all['N'] == 387) & (df_6_15_20_all['name'] == 2)]
df_6_15_20_rb_513 = df_6_15_20_all[(df_6_15_20_all['N'] == 513) & (df_6_15_20_all['name'] == 2)]
df_6_15_20_rb_639 = df_6_15_20_all[(df_6_15_20_all['N'] == 639) & (df_6_15_20_all['name'] == 2)]

# remove first four column
df_6_15_20_n_275 = df_6_15_20_n_275.iloc[:, 4:]
df_6_15_20_n_387 = df_6_15_20_n_387.iloc[:, 4:]
df_6_15_20_n_513 = df_6_15_20_n_513.iloc[:, 4:]
df_6_15_20_n_639 = df_6_15_20_n_639.iloc[:, 4:]
df_6_15_20_no_275 = df_6_15_20_no_275.iloc[:, 4:]
df_6_15_20_no_387 = df_6_15_20_no_387.iloc[:, 4:]
df_6_15_20_no_513 = df_6_15_20_no_513.iloc[:, 4:]
df_6_15_20_no_639 = df_6_15_20_no_639.iloc[:, 4:]
df_6_15_20_rb_275 = df_6_15_20_rb_275.iloc[:, 4:]
df_6_15_20_rb_387 = df_6_15_20_rb_387.iloc[:, 4:]
df_6_15_20_rb_513 = df_6_15_20_rb_513.iloc[:, 4:]
df_6_15_20_rb_639 = df_6_15_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_6_23_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\6_23_2020_LUM_new.xlsx'

df_6_23_20_all = pd.read_excel(LUM_6_23_20, sheet_name='6_23_20_ALL')

# 6_23_20
df_6_23_20_n_275 = df_6_23_20_all[(df_6_23_20_all['N'] == 275) & (df_6_23_20_all['name'] == 3)]
df_6_23_20_n_387 = df_6_23_20_all[(df_6_23_20_all['N'] == 387) & (df_6_23_20_all['name'] == 3)]
df_6_23_20_n_513 = df_6_23_20_all[(df_6_23_20_all['N'] == 513) & (df_6_23_20_all['name'] == 3)]
df_6_23_20_n_639 = df_6_23_20_all[(df_6_23_20_all['N'] == 639) & (df_6_23_20_all['name'] == 3)]

df_6_23_20_no_275 = df_6_23_20_all[(df_6_23_20_all['N'] == 275) & (df_6_23_20_all['name'] == 1)]
df_6_23_20_no_387 = df_6_23_20_all[(df_6_23_20_all['N'] == 387) & (df_6_23_20_all['name'] == 1)]
df_6_23_20_no_513 = df_6_23_20_all[(df_6_23_20_all['N'] == 513) & (df_6_23_20_all['name'] == 1)]
df_6_23_20_no_639 = df_6_23_20_all[(df_6_23_20_all['N'] == 639) & (df_6_23_20_all['name'] == 1)]

df_6_23_20_rb_275 = df_6_23_20_all[(df_6_23_20_all['N'] == 275) & (df_6_23_20_all['name'] == 2)]
df_6_23_20_rb_387 = df_6_23_20_all[(df_6_23_20_all['N'] == 387) & (df_6_23_20_all['name'] == 2)]
df_6_23_20_rb_513 = df_6_23_20_all[(df_6_23_20_all['N'] == 513) & (df_6_23_20_all['name'] == 2)]
df_6_23_20_rb_639 = df_6_23_20_all[(df_6_23_20_all['N'] == 639) & (df_6_23_20_all['name'] == 2)]

# remove first four column
df_6_23_20_n_275 = df_6_23_20_n_275.iloc[:, 4:]
df_6_23_20_n_387 = df_6_23_20_n_387.iloc[:, 4:]
df_6_23_20_n_513 = df_6_23_20_n_513.iloc[:, 4:]
df_6_23_20_n_639 = df_6_23_20_n_639.iloc[:, 4:]
df_6_23_20_no_275 = df_6_23_20_no_275.iloc[:, 4:]
df_6_23_20_no_387 = df_6_23_20_no_387.iloc[:, 4:]
df_6_23_20_no_513 = df_6_23_20_no_513.iloc[:, 4:]
df_6_23_20_no_639 = df_6_23_20_no_639.iloc[:, 4:]
df_6_23_20_rb_275 = df_6_23_20_rb_275.iloc[:, 4:]
df_6_23_20_rb_387 = df_6_23_20_rb_387.iloc[:, 4:]
df_6_23_20_rb_513 = df_6_23_20_rb_513.iloc[:, 4:]
df_6_23_20_rb_639 = df_6_23_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_16_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\7_16_2020_LUM_new.xlsx'

df_7_16_20_all = pd.read_excel(LUM_7_16_20, sheet_name='7_16_20_ALL')

# 7_16_20
df_7_16_20_n_275 = df_7_16_20_all[(df_7_16_20_all['N'] == 275) & (df_7_16_20_all['name'] == 3)]
df_7_16_20_n_387 = df_7_16_20_all[(df_7_16_20_all['N'] == 387) & (df_7_16_20_all['name'] == 3)]
df_7_16_20_n_513 = df_7_16_20_all[(df_7_16_20_all['N'] == 513) & (df_7_16_20_all['name'] == 3)]
df_7_16_20_n_639 = df_7_16_20_all[(df_7_16_20_all['N'] == 639) & (df_7_16_20_all['name'] == 3)]

df_7_16_20_no_275 = df_7_16_20_all[(df_7_16_20_all['N'] == 275) & (df_7_16_20_all['name'] == 1)]
df_7_16_20_no_387 = df_7_16_20_all[(df_7_16_20_all['N'] == 387) & (df_7_16_20_all['name'] == 1)]
df_7_16_20_no_513 = df_7_16_20_all[(df_7_16_20_all['N'] == 513) & (df_7_16_20_all['name'] == 1)]
df_7_16_20_no_639 = df_7_16_20_all[(df_7_16_20_all['N'] == 639) & (df_7_16_20_all['name'] == 1)]

df_7_16_20_rb_275 = df_7_16_20_all[(df_7_16_20_all['N'] == 275) & (df_7_16_20_all['name'] == 2)]
df_7_16_20_rb_387 = df_7_16_20_all[(df_7_16_20_all['N'] == 387) & (df_7_16_20_all['name'] == 2)]
df_7_16_20_rb_513 = df_7_16_20_all[(df_7_16_20_all['N'] == 513) & (df_7_16_20_all['name'] == 2)]
df_7_16_20_rb_639 = df_7_16_20_all[(df_7_16_20_all['N'] == 639) & (df_7_16_20_all['name'] == 2)]

# remove first four column
df_7_16_20_n_275 = df_7_16_20_n_275.iloc[:, 4:]
df_7_16_20_n_387 = df_7_16_20_n_387.iloc[:, 4:]
df_7_16_20_n_513 = df_7_16_20_n_513.iloc[:, 4:]
df_7_16_20_n_639 = df_7_16_20_n_639.iloc[:, 4:]
df_7_16_20_no_275 = df_7_16_20_no_275.iloc[:, 4:]
df_7_16_20_no_387 = df_7_16_20_no_387.iloc[:, 4:]
df_7_16_20_no_513 = df_7_16_20_no_513.iloc[:, 4:]
df_7_16_20_no_639 = df_7_16_20_no_639.iloc[:, 4:]
df_7_16_20_rb_275 = df_7_16_20_rb_275.iloc[:, 4:]
df_7_16_20_rb_387 = df_7_16_20_rb_387.iloc[:, 4:]
df_7_16_20_rb_513 = df_7_16_20_rb_513.iloc[:, 4:]
df_7_16_20_rb_639 = df_7_16_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_21_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\7_21_2020_LUM.xlsx'

df_7_21_20_all = pd.read_excel(LUM_7_21_20, sheet_name='7_21_20_ALL')

# 7_21_20
df_7_21_20_n_275 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 275) & (df_7_21_20_all['variety'] == 'New')]
df_7_21_20_n_387 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 387) & (df_7_21_20_all['variety'] == 'New')]
df_7_21_20_n_4510 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 4510) & (df_7_21_20_all['variety'] == 'New')]
df_7_21_20_n_639 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 639) & (df_7_21_20_all['variety'] == 'New')]

df_7_21_20_no_275 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 275) & (df_7_21_20_all['variety'] == 'Nork')]
df_7_21_20_no_387 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 387) & (df_7_21_20_all['variety'] == 'Nork')]
df_7_21_20_no_4510 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 4510) & (df_7_21_20_all['variety'] == 'Nork')]
df_7_21_20_no_639 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 639) & (df_7_21_20_all['variety'] == 'Nork')]

df_7_21_20_rb_275 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 275) & (df_7_21_20_all['variety'] == 'RB')]
df_7_21_20_rb_387 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 387) & (df_7_21_20_all['variety'] == 'RB')]
df_7_21_20_rb_4510 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 4510) & (df_7_21_20_all['variety'] == 'RB')]
df_7_21_20_rb_639 = df_7_21_20_all[(df_7_21_20_all['N [kg/ha]'] == 639) & (df_7_21_20_all['variety'] == 'RB')]

# remove first four column
df_7_21_20_n_275 = df_7_21_20_n_275.iloc[:, 4:]
df_7_21_20_n_387 = df_7_21_20_n_387.iloc[:, 4:]
df_7_21_20_n_4510 = df_7_21_20_n_4510.iloc[:, 4:]
df_7_21_20_n_639 = df_7_21_20_n_639.iloc[:, 4:]
df_7_21_20_no_275 = df_7_21_20_no_275.iloc[:, 4:]
df_7_21_20_no_387 = df_7_21_20_no_387.iloc[:, 4:]
df_7_21_20_no_4510 = df_7_21_20_no_4510.iloc[:, 4:]
df_7_21_20_no_639 = df_7_21_20_no_639.iloc[:, 4:]
df_7_21_20_rb_275 = df_7_21_20_rb_275.iloc[:, 4:]
df_7_21_20_rb_387 = df_7_21_20_rb_387.iloc[:, 4:]
df_7_21_20_rb_4510 = df_7_21_20_rb_4510.iloc[:, 4:]
df_7_21_20_rb_639 = df_7_21_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_21_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\7_21_2020_LUM_new.xlsx'

df_7_21_20_all = pd.read_excel(LUM_7_21_20, sheet_name='7_21_20_ALL')

# 7_21_20
df_7_21_20_n_275 = df_7_21_20_all[(df_7_21_20_all['N'] == 275) & (df_7_21_20_all['name'] == 3)]
df_7_21_20_n_387 = df_7_21_20_all[(df_7_21_20_all['N'] == 387) & (df_7_21_20_all['name'] == 3)]
df_7_21_20_n_513 = df_7_21_20_all[(df_7_21_20_all['N'] == 513) & (df_7_21_20_all['name'] == 3)]
df_7_21_20_n_639 = df_7_21_20_all[(df_7_21_20_all['N'] == 639) & (df_7_21_20_all['name'] == 3)]

df_7_21_20_no_275 = df_7_21_20_all[(df_7_21_20_all['N'] == 275) & (df_7_21_20_all['name'] == 1)]
df_7_21_20_no_387 = df_7_21_20_all[(df_7_21_20_all['N'] == 387) & (df_7_21_20_all['name'] == 1)]
df_7_21_20_no_513 = df_7_21_20_all[(df_7_21_20_all['N'] == 513) & (df_7_21_20_all['name'] == 1)]
df_7_21_20_no_639 = df_7_21_20_all[(df_7_21_20_all['N'] == 639) & (df_7_21_20_all['name'] == 1)]

df_7_21_20_rb_275 = df_7_21_20_all[(df_7_21_20_all['N'] == 275) & (df_7_21_20_all['name'] == 2)]
df_7_21_20_rb_387 = df_7_21_20_all[(df_7_21_20_all['N'] == 387) & (df_7_21_20_all['name'] == 2)]
df_7_21_20_rb_513 = df_7_21_20_all[(df_7_21_20_all['N'] == 513) & (df_7_21_20_all['name'] == 2)]
df_7_21_20_rb_639 = df_7_21_20_all[(df_7_21_20_all['N'] == 639) & (df_7_21_20_all['name'] == 2)]

# remove first four column
df_7_21_20_n_275 = df_7_21_20_n_275.iloc[:, 4:]
df_7_21_20_n_387 = df_7_21_20_n_387.iloc[:, 4:]
df_7_21_20_n_513 = df_7_21_20_n_513.iloc[:, 4:]
df_7_21_20_n_639 = df_7_21_20_n_639.iloc[:, 4:]
df_7_21_20_no_275 = df_7_21_20_no_275.iloc[:, 4:]
df_7_21_20_no_387 = df_7_21_20_no_387.iloc[:, 4:]
df_7_21_20_no_513 = df_7_21_20_no_513.iloc[:, 4:]
df_7_21_20_no_639 = df_7_21_20_no_639.iloc[:, 4:]
df_7_21_20_rb_275 = df_7_21_20_rb_275.iloc[:, 4:]
df_7_21_20_rb_387 = df_7_21_20_rb_387.iloc[:, 4:]
df_7_21_20_rb_513 = df_7_21_20_rb_513.iloc[:, 4:]
df_7_21_20_rb_639 = df_7_21_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

LUM_7_29_20 = r'C:\Users\say70\Desktop\NX\Code\PLSR\2020\7_29_2020_LUM_new.xlsx'

df_7_29_20_all = pd.read_excel(LUM_7_29_20, sheet_name='7_29_20_ALL')

# 7_29_20
df_7_29_20_n_275 = df_7_29_20_all[(df_7_29_20_all['N'] == 275) & (df_7_29_20_all['name'] == 3)]
df_7_29_20_n_387 = df_7_29_20_all[(df_7_29_20_all['N'] == 387) & (df_7_29_20_all['name'] == 3)]
df_7_29_20_n_513 = df_7_29_20_all[(df_7_29_20_all['N'] == 513) & (df_7_29_20_all['name'] == 3)]
df_7_29_20_n_639 = df_7_29_20_all[(df_7_29_20_all['N'] == 639) & (df_7_29_20_all['name'] == 3)]

df_7_29_20_no_275 = df_7_29_20_all[(df_7_29_20_all['N'] == 275) & (df_7_29_20_all['name'] == 1)]
df_7_29_20_no_387 = df_7_29_20_all[(df_7_29_20_all['N'] == 387) & (df_7_29_20_all['name'] == 1)]
df_7_29_20_no_513 = df_7_29_20_all[(df_7_29_20_all['N'] == 513) & (df_7_29_20_all['name'] == 1)]
df_7_29_20_no_639 = df_7_29_20_all[(df_7_29_20_all['N'] == 639) & (df_7_29_20_all['name'] == 1)]

df_7_29_20_rb_275 = df_7_29_20_all[(df_7_29_20_all['N'] == 275) & (df_7_29_20_all['name'] == 2)]
df_7_29_20_rb_387 = df_7_29_20_all[(df_7_29_20_all['N'] == 387) & (df_7_29_20_all['name'] == 2)]
df_7_29_20_rb_513 = df_7_29_20_all[(df_7_29_20_all['N'] == 513) & (df_7_29_20_all['name'] == 2)]
df_7_29_20_rb_639 = df_7_29_20_all[(df_7_29_20_all['N'] == 639) & (df_7_29_20_all['name'] == 2)]

# remove first four column
df_7_29_20_n_275 = df_7_29_20_n_275.iloc[:, 4:]
df_7_29_20_n_387 = df_7_29_20_n_387.iloc[:, 4:]
df_7_29_20_n_513 = df_7_29_20_n_513.iloc[:, 4:]
df_7_29_20_n_639 = df_7_29_20_n_639.iloc[:, 4:]
df_7_29_20_no_275 = df_7_29_20_no_275.iloc[:, 4:]
df_7_29_20_no_387 = df_7_29_20_no_387.iloc[:, 4:]
df_7_29_20_no_513 = df_7_29_20_no_513.iloc[:, 4:]
df_7_29_20_no_639 = df_7_29_20_no_639.iloc[:, 4:]
df_7_29_20_rb_275 = df_7_29_20_rb_275.iloc[:, 4:]
df_7_29_20_rb_387 = df_7_29_20_rb_387.iloc[:, 4:]
df_7_29_20_rb_513 = df_7_29_20_rb_513.iloc[:, 4:]
df_7_29_20_rb_639 = df_7_29_20_rb_639.iloc[:, 4:]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

#variable_names = ['SR','VF']
#variable_names = ['NDVI','GNDVI','DVI','EVI','EVI2','MARI','CHLRE','CHLGR','SAVI','SAVI2']

variable_names = ['MSAVI','OSAVI','TSAVI','MSR','MCARI','MCARI/OSAVI','PVI','SR','WDRI','VF']
# Calculate the number of rows and columns needed based on the number of variables
num_variables = len(variable_names)
num_rows = math.ceil(num_variables / 1)  # Each row contains 1 variable
num_cols = 5  # Two columns for two dates

# Create subplots for each variable in two columns
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(10, 2.5 * num_variables), sharey='row')

for i, var in enumerate(variable_names):
    # Plot for date 5_28 (left column)
    ax1 = axes[i, 0]
    
    box_color_new = '#FFB6C1'
    box_color_rb = '#ADD8E6'
    box_color_nork = '#90EE90'
    
    df_5_28_new  = [df_5_28_20_n_275[var] , df_5_28_20_n_387[var] , df_5_28_20_n_513[var] , df_5_28_20_n_639[var] ]
    df_5_28_nork = [df_5_28_20_no_275[var], df_5_28_20_no_387[var], df_5_28_20_no_513[var], df_5_28_20_no_639[var]]
    df_5_28_rb   = [df_5_28_20_rb_275[var], df_5_28_20_rb_387[var], df_5_28_20_rb_513[var], df_5_28_20_rb_639[var]]

    ax1.boxplot(df_5_28_new, widths=0.1, positions=[1, 2, 3, 4], patch_artist=True,
                boxprops=dict(facecolor=box_color_new, color=box_color_new),
                whiskerprops=dict(color=box_color_new),
                capprops=dict(color=box_color_new),
                flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                medianprops=dict(color='red'), showfliers=False)

    ax1.boxplot(df_5_28_rb, widths=0.1, positions=[1.2, 2.2, 3.2, 4.2], patch_artist=True,
                boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                whiskerprops=dict(color=box_color_rb),
                capprops=dict(color=box_color_rb),
                flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                medianprops=dict(color='blue'), showfliers=False)

    ax1.boxplot(df_5_28_nork, widths=0.1, positions=[1.4, 2.4, 3.4, 4.4], patch_artist=True,
                boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                whiskerprops=dict(color=box_color_nork, linestyle='-'),
                capprops=dict(color=box_color_nork),
                flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                medianprops=dict(color='green'), showfliers=False)

    ax1.set_xticks([1.2, 2.2, 3.2, 4.2])
    ax1.set_xticklabels(['275', '387', '513', '639'], fontsize=8)
    ax1.set_ylabel(var, fontsize=8)


    if i == num_variables - 1:
        ax1.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax1.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax1.set_xticks([])

    if i == 0:
        ax1.set_title('T1: Emergence', fontsize=10)

    ax1.yaxis.set_major_formatter(
        plt.FuncFormatter(lambda x, _: '{:.1f}'.format(x) if not x.is_integer() else '{:.0f}'.format(x)))
    
    ax1.tick_params(axis='y', labelsize=10)

    # Plot for date 6_03 (right column)
    ax2 = axes[i, 1]

    df_6_03_new = [df_6_03_20_n_275[var], df_6_03_20_n_387[var], df_6_03_20_n_513[var], df_6_03_20_n_639[var]]
    df_6_03_nork = [df_6_03_20_no_275[var], df_6_03_20_no_387[var], df_6_03_20_no_513[var], df_6_03_20_no_639[var]]
    df_6_03_rb = [df_6_03_20_rb_275[var], df_6_03_20_rb_387[var], df_6_03_20_rb_513[var], df_6_03_20_rb_639[var]]
    
    ax2.boxplot(df_6_03_new, widths=0.1, positions=[1, 2, 3, 4], patch_artist=True,
                boxprops=dict(facecolor=box_color_new, color=box_color_new),
                whiskerprops=dict(color=box_color_new),
                capprops=dict(color=box_color_new),
                flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                medianprops=dict(color='red'), showfliers=False)

    ax2.boxplot(df_6_03_rb, widths=0.1, positions=[1.2, 2.2, 3.2, 4.2], patch_artist=True,
                boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                whiskerprops=dict(color=box_color_rb),
                capprops=dict(color=box_color_rb),
                flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                medianprops=dict(color='blue'), showfliers=False)

    ax2.boxplot(df_6_03_nork, widths=0.1, positions=[1.4, 2.4, 3.4, 4.4], patch_artist=True,
                boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                whiskerprops=dict(color=box_color_nork, linestyle='-'),
                capprops=dict(color=box_color_nork),
                flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                medianprops=dict(color='green'), showfliers=False)

    # Plot for date 6_03 (right column)
    #6_10
    df_6_10_new = [df_6_10_20_n_275[var],df_6_10_20_n_387[var],df_6_10_20_n_513[var],df_6_10_20_n_639[var]]
    df_6_10_nork = [df_6_10_20_no_275[var],df_6_10_20_no_387[var],df_6_10_20_no_513[var],df_6_10_20_no_639[var]]
    df_6_10_rb = [df_6_10_20_rb_275[var],df_6_10_20_rb_387[var],df_6_10_20_rb_513[var],df_6_10_20_rb_639[var]]
    
    box_6_10_new = ax2.boxplot(df_6_10_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_6_10_rb = ax2.boxplot(df_6_10_rb, 
                             widths=0.1, 
                             positions=[1.2, 2.2, 3.2, 4.2], 
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    box_6_10_nork = ax2.boxplot(df_6_10_nork, 
                               widths=0.1, 
                               positions=[1.4, 2.4, 3.4, 4.4], 
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)
    ax2.set_xticks([1.2, 2.2, 3.2, 4.2])
    ax2.set_xticklabels(['275', '387', '513', '639'], fontsize=8)
    
    if i == num_variables - 1:
        ax2.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax2.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax2.set_xticks([])
    if i == 0:
        ax2.set_title('T2: Vegetative', fontsize=10)





    # Plot for date 6_03 (right column)
    ax3 = axes[i, 2]
    #6_15
    df_6_15_new = [df_6_15_20_n_275[var],
                   df_6_15_20_n_387[var],
                   df_6_15_20_n_513[var],
                   df_6_15_20_n_639[var]]

    df_6_15_nork = [df_6_15_20_no_275[var],
                    df_6_15_20_no_387[var],
                    df_6_15_20_no_513[var],
                    df_6_15_20_no_639[var]]

    df_6_15_rb = [df_6_15_20_rb_275[var],
                  df_6_15_20_rb_387[var],
                  df_6_15_20_rb_513[var],
                  df_6_15_20_rb_639[var]]
    

    box_6_15_new = ax3.boxplot(df_6_15_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_6_15_rb = ax3.boxplot(df_6_15_rb, 
                             widths=0.1, 
                             positions=[1.2, 2.2, 3.2, 4.2], 
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    box_6_15_nork = ax3.boxplot(df_6_15_nork, 
                               widths=0.1, 
                               positions=[1.4, 2.4, 3.4, 4.4], 
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    #6_23
    df_6_23_new = [df_6_23_20_n_275[var],
                   df_6_23_20_n_387[var],
                   df_6_23_20_n_513[var],
                   df_6_23_20_n_639[var]]

    df_6_23_nork = [df_6_23_20_no_275[var],
                    df_6_23_20_no_387[var],
                    df_6_23_20_no_513[var],
                    df_6_23_20_no_639[var]]

    df_6_23_rb = [df_6_23_20_rb_275[var],
                  df_6_23_20_rb_387[var],
                  df_6_23_20_rb_513[var],
                  df_6_23_20_rb_639[var]]
    
    box_6_23_new = ax3.boxplot(df_6_23_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_6_23_rb = ax3.boxplot(df_6_23_rb, 
                             widths=0.1, 
                             positions=[1.2, 2.2, 3.2, 4.2], 
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    box_6_23_nork = ax3.boxplot(df_6_23_nork, 
                               widths=0.1, 
                               positions=[1.4, 2.4, 3.4, 4.4], 
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)
    
    ax3.set_xticks([1.2, 2.2, 3.2, 4.2])
    ax3.set_xticklabels(['275', '387', '513', '639'], fontsize=8)
    
    if i == num_variables - 1:
        ax3.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax3.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax3.set_xticks([])

    if i == 0:
        ax3.set_title('T3: Tuberization', fontsize=10)


     # Plot for date 7_16 (right column)
    ax4 = axes[i, 3]
    
    df_7_16_new = [df_7_16_20_n_275[var],
                   df_7_16_20_n_387[var],
                   df_7_16_20_n_513[var],
                   df_7_16_20_n_639[var]]

    df_7_16_nork = [df_7_16_20_no_275[var],
                    df_7_16_20_no_387[var],
                    df_7_16_20_no_513[var],
                    df_7_16_20_no_639[var]]

    df_7_16_rb = [df_7_16_20_rb_275[var],
                  df_7_16_20_rb_387[var],
                  df_7_16_20_rb_513[var],
                  df_7_16_20_rb_639[var]]
    

   

    box_7_16_new = ax4.boxplot(df_7_16_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_7_16_rb = ax4.boxplot(df_7_16_rb, 
                             widths=0.1, 
                             positions=[1.2, 2.2, 3.2, 4.2], 
                             patch_artist=True,
                             boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                             whiskerprops=dict(color=box_color_rb),
                             capprops=dict(color=box_color_rb),
                             flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                             medianprops=dict(color='blue'),showfliers=False)

    box_7_16_nork = ax4.boxplot(df_7_16_nork, 
                               widths=0.1, 
                               positions=[1.4, 2.4, 3.4, 4.4], 
                               patch_artist=True,
                               boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                               whiskerprops=dict(color=box_color_nork, linestyle='-'),
                               capprops=dict(color=box_color_nork),
                               flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                               medianprops=dict(color='green'),showfliers=False)

    df_7_21_new = [df_7_21_20_n_275[var],
                   df_7_21_20_n_387[var],
                   df_7_21_20_n_513[var],
                   df_7_21_20_n_639[var]]

    df_7_21_nork = [df_7_21_20_no_275[var],
                    df_7_21_20_no_387[var],
                    df_7_21_20_no_513[var],
                    df_7_21_20_no_639[var]]

    df_7_21_rb = [df_7_21_20_rb_275[var],
                  df_7_21_20_rb_387[var],
                  df_7_21_20_rb_513[var],
                  df_7_21_20_rb_639[var]]
    

    box_7_21_new = ax4.boxplot(df_7_21_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_7_21_rb = ax4.boxplot(df_7_21_rb, 
                                 widths=0.1, 
                                 positions=[1.2, 2.2, 3.2, 4.2], 
                                 patch_artist=True,
                                 boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                                 whiskerprops=dict(color=box_color_rb),
                                 capprops=dict(color=box_color_rb),
                                 flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                                 medianprops=dict(color='blue'),showfliers=False)

    box_7_21_nork = ax4.boxplot(df_7_21_nork, 
                                   widths=0.1, 
                                   positions=[1.4, 2.4, 3.4, 4.4], 
                                   patch_artist=True,
                                   boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                                   whiskerprops=dict(color=box_color_nork, linestyle='-'),
                                   capprops=dict(color=box_color_nork),
                                   flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                                   medianprops=dict(color='green'),showfliers=False)


    ax4.set_xticks([1.2, 2.2, 3.2, 4.2])
    ax4.set_xticklabels(['275', '387', '513', '639'], fontsize=8)
    
    if i == num_variables - 1:
        ax4.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax4.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax4.set_xticks([])
    if i == 0:
        ax4.set_title('T4: Bulking', fontsize=10)


    # Plot for date 7_16 (right column)
    ax5 = axes[i, 4]

    #7_29
    df_7_29_new = [df_7_29_20_n_275[var],
                   df_7_29_20_n_387[var],
                   df_7_29_20_n_513[var],
                   df_7_29_20_n_639[var]]

    df_7_29_nork = [df_7_29_20_no_275[var],
                    df_7_29_20_no_387[var],
                    df_7_29_20_no_513[var],
                    df_7_29_20_no_639[var]]

    df_7_29_rb = [df_7_29_20_rb_275[var],
                  df_7_29_20_rb_387[var],
                  df_7_29_20_rb_513[var],
                  df_7_29_20_rb_639[var]]
    

    box_7_29_new = ax5.boxplot(df_7_29_new, 
                              widths=0.1, 
                              positions=[1, 2, 3, 4], 
                              patch_artist=True,
                              boxprops=dict(facecolor=box_color_new, color=box_color_new),
                              whiskerprops=dict(color=box_color_new),
                              capprops=dict(color=box_color_new),
                              flierprops=dict(markerfacecolor=box_color_new, markeredgecolor='red', markersize=5),
                              medianprops=dict(color='red'),showfliers=False)

    box_7_29_rb = ax5.boxplot(df_7_29_rb, 
                                 widths=0.1, 
                                 positions=[1.2, 2.2, 3.2, 4.2], 
                                 patch_artist=True,
                                 boxprops=dict(facecolor=box_color_rb, color=box_color_rb),
                                 whiskerprops=dict(color=box_color_rb),
                                 capprops=dict(color=box_color_rb),
                                 flierprops=dict(markerfacecolor=box_color_rb, markeredgecolor='blue', markersize=5),
                                 medianprops=dict(color='blue'),showfliers=False)

    box_7_29_nork = ax5.boxplot(df_7_29_nork, 
                                   widths=0.1, 
                                   positions=[1.4, 2.4, 3.4, 4.4], 
                                   patch_artist=True,
                                   boxprops=dict(facecolor=box_color_nork, color=box_color_nork),
                                   whiskerprops=dict(color=box_color_nork, linestyle='-'),
                                   capprops=dict(color=box_color_nork),
                                   flierprops=dict(markerfacecolor=box_color_nork, markeredgecolor='green', markersize=5),
                                   medianprops=dict(color='green'),showfliers=False)


    ax5.set_xticks([1.2, 2.2, 3.2, 4.2])
    ax5.set_xticklabels(['275', '387', '513', '639'], fontsize=8)
    
    if i == num_variables - 1:
        ax5.set_xlabel('N [kg/ha]', fontsize=8)
    else:
        ax5.set_xticklabels([])  # Remove x tick labels for all but the bottom row
        ax5.set_xticks([])
           
    if i == 0:
        ax5.set_title('T5: Maturity', fontsize=10)

    
# Adjust layout to include legend
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.subplots_adjust(hspace=0.09, wspace=0.09)
plt.savefig('C:/Users/Say70/OneDrive - Mississippi State University/Desktop/Yield monitoring_new/2020_2_all.png', dpi=1500, bbox_inches='tight')
plt.show()
